# %%
'''
1三名面试者的基本数据如下：
序号	年龄	工作经历（年）	所学专业
1	24	0	计算机
2	32	4	电子
3	36	8	电子
4	26	2	通信
分别输入每一位面试者的基本数据，输出是否符合面试要求，面试要求为：
1)计算机专业，年龄小于25岁
2)电子专业，有4年以上工作经验
3)通信专业都可以
满足面试要求的，输出“获得面试机会”，不满足要求的，输出“抱歉，您不符合面试要求”
'''
age=int(input("年龄："))
year=int(input("工作经历（年）："))
major=input("所学专业：")
if major=='计算机' and age<25:
    print('获得面试机会!')
elif major=='电子' and year>4:
    print('获得面试机会!')
elif major=='通信':
    print('获得面试机会!')
else:
    print('抱歉，您不符合面试要求!')
# Out:
# 年龄：10
# 工作经历（年）：0
# 所学专业：0
# 抱歉，您不符合面试要求!

# %%
#2输入小明百分制成绩，输出相应的等级：90分以上为‘A’，80分到89分为‘B’，70分到7分为‘C’，60分到69分为‘D’，60分以下为‘E’，如果分数大于100或者小于0，则输出“成绩有误”。
score=eval(input("百分制成绩："))
if 90<=score<100:
    print('A')
elif 80<=score<90:
    print('B')
elif 70<=score<80:
    print('C')
elif 60<=score<70:
    print('D')
elif 0<=score<60:
    print('E')
else:
    print('成绩有误')
# Out:
# 百分制成绩：20
# E

# %%
#3编写程序，输出2000到3000之间所有的闰年。

for i in range(2000,3000+1):
    if (i%4==0 and i%100!=0)or(i%400==0):
        print(i)
# Out:
# 2000
# 2004
# 2008
# 2012
# 2016
# 2020
# 2024
# 2028
# 2032
# 2036
# 2040
# 2044
# 2048
# 2052
# 2056
# 2060
# 2064
# 2068
# 2072
# 2076
# 2080
# 2084
# 2088
# 2092
# 2096
# 2104
# 2108
# 2112
# 2116
# 2120
# 2124
# 2128
# 2132
# 2136
# 2140
# 2144
# 2148
# 2152
# 2156
# 2160
# 2164
# 2168
# 2172
# 2176
# 2180
# 2184
# 2188
# 2192
# 2196
# 2204
# 2208
# 2212
# 2216
# 2220
# 2224
# 2228
# 2232
# 2236
# 2240
# 2244
# 2248
# 2252
# 2256
# 2260
# 2264
# 2268
# 2272
# 2276
# 2280
# 2284
# 2288
# 2292
# 2296
# 2304
# 2308
# 2312
# 2316
# 2320
# 2324
# 2328
# 2332
# 2336
# 2340
# 2344
# 2348
# 2352
# 2356
# 2360
# 2364
# 2368
# 2372
# 2376
# 2380
# 2384
# 2388
# 2392
# 2396
# 2400
# 2404
# 2408
# 2412
# 2416
# 2420
# 2424
# 2428
# 2432
# 2436
# 2440
# 2444
# 2448
# 2452
# 2456
# 2460
# 2464
# 2468
# 2472
# 2476
# 2480
# 2484
# 2488
# 2492
# 2496
# 2504
# 2508
# 2512
# 2516
# 2520
# 2524
# 2528
# 2532
# 2536
# 2540
# 2544
# 2548
# 2552
# 2556
# 2560
# 2564
# 2568
# 2572
# 2576
# 2580
# ...

# %%
#4编写程序，输出0到90°之间（包括端点）每隔5°的角度值以及其正弦，余弦函数值。

import math
for i in range(0,90+1,5):
    ii=math.radians(i)
    print('sin({})={},  cos({})={}'.format(i,math.sin(ii),i,math.cos(ii)))
# Out:
# sin(0)=0.0,  cos(0)=1.0
# sin(5)=0.08715574274765817,  cos(5)=0.9961946980917455
# sin(10)=0.17364817766693033,  cos(10)=0.984807753012208
# sin(15)=0.25881904510252074,  cos(15)=0.9659258262890683
# sin(20)=0.3420201433256687,  cos(20)=0.9396926207859084
# sin(25)=0.42261826174069944,  cos(25)=0.9063077870366499
# sin(30)=0.49999999999999994,  cos(30)=0.8660254037844387
# sin(35)=0.573576436351046,  cos(35)=0.8191520442889918
# sin(40)=0.6427876096865393,  cos(40)=0.766044443118978
# sin(45)=0.7071067811865476,  cos(45)=0.7071067811865476
# sin(50)=0.766044443118978,  cos(50)=0.6427876096865394
# sin(55)=0.8191520442889918,  cos(55)=0.573576436351046
# sin(60)=0.8660254037844386,  cos(60)=0.5000000000000001
# sin(65)=0.9063077870366499,  cos(65)=0.42261826174069944
# sin(70)=0.9396926207859083,  cos(70)=0.3420201433256688
# sin(75)=0.9659258262890683,  cos(75)=0.25881904510252074
# sin(80)=0.984807753012208,  cos(80)=0.17364817766693041
# ...

# %%
#5输入正整数n，求n以内能被17整除的最大正整数。

n=int(input('输入一个正整数：'))
while(n>=17):
    if n%17==0:
        print(n)
        break
    else:
        n-=1
else:
    print('n<17,无法找到')
# Out:
# 输入一个正整数： 15
# n<17,无法找到

# %%
#6编写程序，计算S=1+1/3-1/5+1/7-1/9……前n项的结果。

n=int(input('输入项数：'))
s=1
for i in range(1,n):
    f=(-1)**(i+1)*(2*i+1)
    ss=1/f
    s+=ss
print("s=",s)
# Out:
# 输入项数： 8
# s= 1.2457320457320455

# %%
#7产生1到100之间（包含1和100）的三个随机整数a，b和c，求a，b，c的最大公约数和最小公倍数。

import random
a=random.randint(1,100)
b=random.randint(1,100)
c=random.randint(1,100)
print("a=",a,"  b=",b,"  c=",c)
for i in range(min(a,b,c),0,-1):
    if a%i==0 and b%i==0 and c%i==0:
        print("最大公约数：",i)
        break
    
for i in range(max(a,b,c),a*b*c+1):
    if i%a==0 and i%b==0 and i%c==0:
        print("最小公倍数：",i)
        break
# Out:
# a= 21   b= 13   c= 75
# 最大公约数： 1
# 最小公倍数： 6825

# %%
#九九乘法表
# 外层循环控制行数，从1到9
for i in range(1, 10):  
    # 内层循环控制每行的列数，从1到当前行号i
    for j in range(1, i + 1):  
        # 打印乘法表的每一项，格式为"j * i = 结果"，并用制表符分隔
        # end参数设置为"\t"，表示打印后不换行，而是打印一个制表符
        print(f"{j} * {i} = {i * j}", end="\t")  
    # 每打印完一行后换行，准备打印下一行
    print()
# Out:
# 1 * 1 = 1
# 1 * 2 = 2	2 * 2 = 4
# 1 * 3 = 3	2 * 3 = 6	3 * 3 = 9
# 1 * 4 = 4	2 * 4 = 8	3 * 4 = 12	4 * 4 = 16
# 1 * 5 = 5	2 * 5 = 10	3 * 5 = 15	4 * 5 = 20	5 * 5 = 25
# 1 * 6 = 6	2 * 6 = 12	3 * 6 = 18	4 * 6 = 24	5 * 6 = 30	6 * 6 = 36
# 1 * 7 = 7	2 * 7 = 14	3 * 7 = 21	4 * 7 = 28	5 * 7 = 35	6 * 7 = 42	7 * 7 = 49
# 1 * 8 = 8	2 * 8 = 16	3 * 8 = 24	4 * 8 = 32	5 * 8 = 40	6 * 8 = 48	7 * 8 = 56	8 * 8 = 64
# 1 * 9 = 9	2 * 9 = 18	3 * 9 = 27	4 * 9 = 36	5 * 9 = 45	6 * 9 = 54	7 * 9 = 63	8 * 9 = 72	9 * 9 = 81
